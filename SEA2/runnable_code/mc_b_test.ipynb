# %%
import numpy as np

from etas.mc_b_est import estimate_mc, round_half_up

# %%
if __name__ == '__main__':
    magnitude_sample = np.load(r"C:\Users\Dakshata\OneDrive - iitgn.ac.in\Thesis\Thesis\All_SEA\SEA2\InputData\magnitudes.npy")

    mcs = round_half_up(np.arange(1.7, 7.5, 0.1), 1)
    mcs_tested, ks_distances, p_values, mc_winner, beta_winner = estimate_mc(
        magnitude_sample,
        mcs,
        delta_m=0.1,
        p_pass=0.05,
        stop_when_passed=True,
        verbose=True,
        n_samples=1000
    )
# Out:
# testing mc 1.7
# ..p-value:  0.0
#
# testing mc 1.8
# ..p-value:  0.0
#
# testing mc 1.9
# ..p-value:  0.0
#
# testing mc 2.0
# ..p-value:  0.0
#
# testing mc 2.1
# ..p-value:  0.0
#
# testing mc 2.2
# ..p-value:  0.0
#
# testing mc 2.3
# ..p-value:  0.0
#
# testing mc 2.4
# ..p-value:  0.0
#
# testing mc 2.5
# ..p-value:  0.0
#
# testing mc 2.6
# ..p-value:  0.0
#
# testing mc 2.7
# ..p-value:  0.0
#
# testing mc 2.8
# ..p-value:  0.0
#
# testing mc 2.9
# ..p-value:  0.0
#
# testing mc 3.0
# ..p-value:  0.0
#
# testing mc 3.1
# ..p-value:  0.0
#
# testing mc 3.2
# ..p-value:  0.0
#
# testing mc 3.3
# ..p-value:  0.0
#
# testing mc 3.4
# ..p-value:  0.0
#
# testing mc 3.5
# ..p-value:  0.0
#
# testing mc 3.6
# ..p-value:  0.0
#
# testing mc 3.7
# ..p-value:  0.0
#
# testing mc 3.8
# ..p-value:  0.0
#
# testing mc 3.9
# ..p-value:  0.0
#
# testing mc 4.0
# ..p-value:  0.0
#
# testing mc 4.1
# ..p-value:  0.0
#
# testing mc 4.2
# ..p-value:  0.0
#
# testing mc 4.3
# ..p-value:  0.0
#
# ...
