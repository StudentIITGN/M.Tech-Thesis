# %%
import json
import logging

# %%
from etas import set_up_logger
from etas.inversion import ETASParameterCalculation

set_up_logger(level=logging.DEBUG)

if __name__=='__main__':
    with open(r"C:\Users\Dakshata\OneDrive - iitgn.ac.in\Thesis\Thesis\All_SEA\SEA1\config\invert_etas_config.json",'r') as f:
         inversion_config=json.load(f)
            
    calculation=ETASParameterCalculation(inversion_config)
    calculation.prepare()
    parameters=calculation.invert()
    calculation.store_results(inversion_config['data_path'],store_pij=True)
    
    print("Done!")
# Out:
# 27-08-24 12:03:28 : INFO     : etas.inversion  - INITIALIZING...
# 27-08-24 12:03:28 : INFO     : etas.inversion  -   model is named NoName ETAS Model, has ID 0
# 27-08-24 12:03:28 : INFO     : etas.inversion  -   Time Window:
#       1978-07-29 09:19:00 (aux start)
#       1991-01-22 11:41:00 (start)
#       2023-05-14 21:43:00 (end).
# 27-08-24 12:03:28 : INFO     : etas.inversion  -   free_productivity: False, free_background: False
# 27-08-24 12:03:28 : INFO     : etas.inversion  - PREPARING NoName ETAS Model
# 27-08-24 12:03:28 : INFO     : etas.inversion  -   filtering catalog...
# 27-08-24 12:03:28 : INFO     : etas.inversion  -   3720 out of 3974 events are within time window.
# 27-08-24 12:03:28 : INFO     : etas.inversion  -   Coordinates of region: [array([ 8.8059, 95.348 ]), array([ 11.7811, 100.1231]), array([16.2764, 99.9211]), array([17.6501, 97.8433]), array([17.73, 94.58]), array([17.7282, 92.1736]), array([17.4987, 81.8441]), array([14.4654, 83.0456]), array([ 9.2454, 85.5082]), array([ 9.0717, 85.8   ]), array([ 8.811 , 90.2306]), array([ 8.7873, 91.9955]), array([ 8.7823, 93.194 ]), array([ 8.7814, 93.9009]), array([ 8.7816, 93.9902])]
# C:\Users\Dakshata\anaconda3\Lib\site-packages\shapely\ops.py:276: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   shell = type(geom.exterior)(zip(*func(*zip(*geom.exterior.coords))))
# 27-08-24 12:03:28 : INFO     : etas.inversion  - Region has 1624571.8602933122 square km
# 27-08-24 12:03:28 : INFO     : etas.inversion  - 3720 events lie within target region.
# 27-08-24 12:03:28 : INFO     : etas.inversion  - 906 events are above completeness.
# 27-08-24 12:03:28 : INFO     : etas.inversion  -   using input initial values for theta
# 27-08-24 12:03:28 : INFO     : etas.inversion  -   calculating distances...
# 27-08-24 12:03:28 : INFO     : etas.inversion  -     beta is 2.9580502017062082
# 27-08-24 12:03:28 : INFO     : etas.inversion  -   number of sources: 906
# 27-08-24 12:03:28 : INFO     : etas.inversion  -   number of targets: 728
# 27-08-24 12:03:33 : DEBUG    : etas.inversion  -   took 0:00:04.663386 to prepare the data
# 27-08-24 12:03:33 : INFO     : etas.inversion  -   preparing source and target events..
# 27-08-24 12:03:33 : INFO     : etas.inversion  -   beta of primary catalog is 2.9580502017062082
# 27-08-24 12:03:33 : INFO     : etas.inversion  - START INVERSION
# 27-08-24 12:03:33 : INFO     : etas.inversion  -   iteration 0
# 27-08-24 12:03:33 : DEBUG    : etas.inversion  -     expectation step
# 27-08-24 12:03:33 : DEBUG    : etas.inversion  -     calculating gij
# 27-08-24 12:03:33 : DEBUG    : etas.inversion  -     calculating Pij
# 27-08-24 12:03:33 : DEBUG    : etas.inversion  -     calculating n_hat and l_hat
# 27-08-24 12:03:33 : DEBUG    : etas.inversion  -     expectation step took 0:00:00.154419
# 27-08-24 12:03:33 : DEBUG    : etas.inversion  - n_hat: 420.30664263158224
# 27-08-24 12:03:33 : DEBUG    : etas.inversion  - i_hat: 0
# 27-08-24 12:03:33 : DEBUG    : etas.inversion  - optimizing parameters
# C:\Users\Dakshata\anaconda3\Lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# 27-08-24 12:03:45 : DEBUG    : etas.inversion  -     optimization step took 0:00:11.478552
# 27-08-24 12:03:45 : INFO     : etas.inversion  - new parameters:
# 27-08-24 12:03:45 : INFO     : etas.inversion  - {   'a': 1.7594808711099463,
#     'gamma': 0.569245475104506,
#     'log10_c': -1.659506531142113,
#     'log10_d': 1.4334939114764929,
#     'log10_iota': None,
#     'log10_k0': -0.9640077163426561,
#     'log10_mu': -7.659070066065409,
#     'log10_tau': 3.5182224479969952,
#     'omega': 0.25428427848684293,
#     'rho': 0.8459012878715518}
# 27-08-24 12:03:45 : INFO     : etas.inversion  -  difference to previous: 7.86873139819807
# 27-08-24 12:03:45 : DEBUG    : etas.inversion  -  branching ratio: 0.8635979514563724
# 27-08-24 12:03:45 : INFO     : etas.inversion  -   iteration 1
# 27-08-24 12:03:45 : DEBUG    : etas.inversion  -     expectation step
# 27-08-24 12:03:45 : DEBUG    : etas.inversion  -     calculating gij
# 27-08-24 12:03:45 : DEBUG    : etas.inversion  -     calculating Pij
# 27-08-24 12:03:45 : DEBUG    : etas.inversion  -     calculating n_hat and l_hat
# 27-08-24 12:03:45 : DEBUG    : etas.inversion  -     expectation step took 0:00:00.092068
# 27-08-24 12:03:45 : DEBUG    : etas.inversion  - n_hat: 224.90423018359024
# 27-08-24 12:03:45 : DEBUG    : etas.inversion  - i_hat: 0
# 27-08-24 12:03:45 : DEBUG    : etas.inversion  - optimizing parameters
# 27-08-24 12:03:56 : DEBUG    : etas.inversion  -     optimization step took 0:00:11.170470
# 27-08-24 12:03:56 : INFO     : etas.inversion  - new parameters:
# 27-08-24 12:03:56 : INFO     : etas.inversion  - {   'a': 1.5098137983040198,
#     'gamma': 0.4452753707038463,
#     'log10_c': -1.9514725336145213,
#     'log10_d': 1.6909028750780466,
#     'log10_iota': None,
#     'log10_k0': -0.8833781815399625,
#     'log10_mu': -7.930638695744009,
#     'log10_tau': 3.4307662004796002,
#     'omega': 0.08311964431146644,
#     'rho': 0.7014542806371474}
# 27-08-24 12:03:56 : INFO     : etas.inversion  -  difference to previous: 1.678278196689018
# 27-08-24 12:03:56 : DEBUG    : etas.inversion  -  branching ratio: 0.4255799837780608
# 27-08-24 12:03:56 : INFO     : etas.inversion  -   iteration 2
# 27-08-24 12:03:56 : DEBUG    : etas.inversion  -     expectation step
# 27-08-24 12:03:56 : DEBUG    : etas.inversion  -     calculating gij
# 27-08-24 12:03:56 : DEBUG    : etas.inversion  -     calculating Pij
# 27-08-24 12:03:56 : DEBUG    : etas.inversion  -     calculating n_hat and l_hat
# 27-08-24 12:03:56 : DEBUG    : etas.inversion  -     expectation step took 0:00:00.093371
# 27-08-24 12:03:56 : DEBUG    : etas.inversion  - n_hat: 133.1963203675313
# 27-08-24 12:03:56 : DEBUG    : etas.inversion  - i_hat: 0
# 27-08-24 12:03:56 : DEBUG    : etas.inversion  - optimizing parameters
# 27-08-24 12:04:07 : DEBUG    : etas.inversion  -     optimization step took 0:00:10.640820
# 27-08-24 12:04:07 : INFO     : etas.inversion  - new parameters:
# 27-08-24 12:04:07 : INFO     : etas.inversion  - {   'a': 1.3320391032732577,
#     'gamma': 0.3230090291295346,
#     'log10_c': -2.245250292035982,
#     'log10_d': 1.8459793259837016,
#     'log10_iota': None,
#     'log10_k0': -0.7974510545816147,
#     'log10_mu': -8.158144092483322,
#     'log10_tau': 3.569002188898348,
#     'omega': 0.0031938899956101556,
#     'rho': 0.6811157026057126}
# 27-08-24 12:04:07 : INFO     : etas.inversion  -  difference to previous: 1.3008280903958895
# 27-08-24 12:04:07 : DEBUG    : etas.inversion  -  branching ratio: 0.6985635588172444
# 27-08-24 12:04:07 : INFO     : etas.inversion  -   iteration 3
# 27-08-24 12:04:07 : DEBUG    : etas.inversion  -     expectation step
# 27-08-24 12:04:07 : DEBUG    : etas.inversion  -     calculating gij
# 27-08-24 12:04:07 : DEBUG    : etas.inversion  -     calculating Pij
# 27-08-24 12:04:07 : DEBUG    : etas.inversion  -     calculating n_hat and l_hat
# 27-08-24 12:04:07 : DEBUG    : etas.inversion  -     expectation step took 0:00:00.095445
# 27-08-24 12:04:07 : DEBUG    : etas.inversion  - n_hat: 83.27542170108445
# 27-08-24 12:04:07 : DEBUG    : etas.inversion  - i_hat: 0
# 27-08-24 12:04:07 : DEBUG    : etas.inversion  - optimizing parameters
# 27-08-24 12:04:15 : DEBUG    : etas.inversion  -     optimization step took 0:00:08.478727
# 27-08-24 12:04:15 : INFO     : etas.inversion  - new parameters:
# 27-08-24 12:04:15 : INFO     : etas.inversion  - {   'a': 1.1927440544979908,
#     'gamma': 0.21243703687184273,
#     'log10_c': -2.4199483273461135,
#     'log10_d': 1.9453214815044124,
#     'log10_iota': None,
#     'log10_k0': -0.7202739743868397,
#     'log10_mu': -8.36211947921742,
#     'log10_tau': 3.708817945736197,
#     'omega': -0.027924151755964733,
#     'rho': 0.6810471749298197}
# 27-08-24 12:04:15 : INFO     : etas.inversion  -  difference to previous: 0.9760620250579901
# 27-08-24 12:04:15 : DEBUG    : etas.inversion  -  branching ratio: 0.8312304082023207
# 27-08-24 12:04:15 : INFO     : etas.inversion  -   iteration 4
# 27-08-24 12:04:15 : DEBUG    : etas.inversion  -     expectation step
# 27-08-24 12:04:15 : DEBUG    : etas.inversion  -     calculating gij
# 27-08-24 12:04:15 : DEBUG    : etas.inversion  -     calculating Pij
# 27-08-24 12:04:15 : DEBUG    : etas.inversion  -     calculating n_hat and l_hat
# 27-08-24 12:04:15 : DEBUG    : etas.inversion  -     expectation step took 0:00:00.090516
# 27-08-24 12:04:15 : DEBUG    : etas.inversion  - n_hat: 57.552194326086465
# 27-08-24 12:04:15 : DEBUG    : etas.inversion  - i_hat: 0
# 27-08-24 12:04:15 : DEBUG    : etas.inversion  - optimizing parameters
# 27-08-24 12:04:26 : DEBUG    : etas.inversion  -     optimization step took 0:00:10.408069
# 27-08-24 12:04:26 : INFO     : etas.inversion  - new parameters:
# 27-08-24 12:04:26 : INFO     : etas.inversion  - {   'a': 1.087664886937543,
#     'gamma': 0.12229204526610428,
#     'log10_c': -2.514798996677792,
#     'log10_d': 2.0083504267197037,
#     'log10_iota': None,
#     'log10_k0': -0.6637433690504528,
#     'log10_mu': -8.522574432943438,
#     'log10_tau': 3.7976183921617563,
#     'omega': -0.04190320224568902,
#     'rho': 0.6841657484114524}
# 27-08-24 12:04:26 : INFO     : etas.inversion  -  difference to previous: 0.675987403172478
# 27-08-24 12:04:26 : DEBUG    : etas.inversion  -  branching ratio: 0.9082802199965898
# 27-08-24 12:04:26 : INFO     : etas.inversion  -   iteration 5
# 27-08-24 12:04:26 : DEBUG    : etas.inversion  -     expectation step
# 27-08-24 12:04:26 : DEBUG    : etas.inversion  -     calculating gij
# 27-08-24 12:04:26 : DEBUG    : etas.inversion  -     calculating Pij
# 27-08-24 12:04:26 : DEBUG    : etas.inversion  -     calculating n_hat and l_hat
# 27-08-24 12:04:26 : DEBUG    : etas.inversion  -     expectation step took 0:00:00.089856
# 27-08-24 12:04:26 : DEBUG    : etas.inversion  - n_hat: 44.56255473054521
# 27-08-24 12:04:26 : DEBUG    : etas.inversion  - i_hat: 0
# 27-08-24 12:04:26 : DEBUG    : etas.inversion  - optimizing parameters
# 27-08-24 12:04:36 : DEBUG    : etas.inversion  -     optimization step took 0:00:10.446756
# 27-08-24 12:04:36 : INFO     : etas.inversion  - new parameters:
# 27-08-24 12:04:36 : INFO     : etas.inversion  - {   'a': 1.0110128820893827,
#     'gamma': 0.05394731734448573,
#     'log10_c': -2.565284879019745,
#     'log10_d': 2.047943290964581,
#     'log10_iota': None,
#     'log10_k0': -0.6256577750102492,
#     'log10_mu': -8.63366623923878,
#     'log10_tau': 3.843509411541072,
#     'omega': -0.04880186360873156,
#     'rho': 0.6868250713227385}
# 27-08-24 12:04:36 : INFO     : etas.inversion  -  difference to previous: 0.4397018833457986
# 27-08-24 12:04:36 : DEBUG    : etas.inversion  -  branching ratio: 0.9511895074652238
# 27-08-24 12:04:36 : INFO     : etas.inversion  -   iteration 6
# 27-08-24 12:04:36 : DEBUG    : etas.inversion  -     expectation step
# 27-08-24 12:04:36 : DEBUG    : etas.inversion  -     calculating gij
# 27-08-24 12:04:36 : DEBUG    : etas.inversion  -     calculating Pij
# 27-08-24 12:04:36 : DEBUG    : etas.inversion  -     calculating n_hat and l_hat
# 27-08-24 12:04:36 : DEBUG    : etas.inversion  -     expectation step took 0:00:00.090944
# 27-08-24 12:04:36 : DEBUG    : etas.inversion  - n_hat: 37.930681273212386
# 27-08-24 12:04:36 : DEBUG    : etas.inversion  - i_hat: 0
# 27-08-24 12:04:36 : DEBUG    : etas.inversion  - optimizing parameters
# 27-08-24 12:04:47 : DEBUG    : etas.inversion  -     optimization step took 0:00:10.121243
# 27-08-24 12:04:47 : INFO     : etas.inversion  - new parameters:
# 27-08-24 12:04:47 : INFO     : etas.inversion  - {   'a': 0.9571016383858684,
#     'gamma': 0.004991477408530994,
#     'log10_c': -2.5920338151289357,
#     'log10_d': 2.072538287710689,
#     'log10_iota': None,
#     'log10_k0': -0.6012484114001017,
#     'log10_mu': -8.703645676685138,
#     'log10_tau': 3.865377243155159,
#     'omega': -0.05233384688091048,
#     'rho': 0.6885078138816916}
# 27-08-24 12:04:47 : INFO     : etas.inversion  -  difference to previous: 0.27568237499649256
# 27-08-24 12:04:47 : DEBUG    : etas.inversion  -  branching ratio: 0.973960252002744
# 27-08-24 12:04:47 : INFO     : etas.inversion  -   iteration 7
# 27-08-24 12:04:47 : DEBUG    : etas.inversion  -     expectation step
# 27-08-24 12:04:47 : DEBUG    : etas.inversion  -     calculating gij
# 27-08-24 12:04:47 : DEBUG    : etas.inversion  -     calculating Pij
# 27-08-24 12:04:47 : DEBUG    : etas.inversion  -     calculating n_hat and l_hat
# 27-08-24 12:04:47 : DEBUG    : etas.inversion  -     expectation step took 0:00:00.103918
# 27-08-24 12:04:47 : DEBUG    : etas.inversion  - n_hat: 34.47435411707651
# 27-08-24 12:04:47 : DEBUG    : etas.inversion  - i_hat: 0
# 27-08-24 12:04:47 : DEBUG    : etas.inversion  - optimizing parameters
# 27-08-24 12:04:55 : DEBUG    : etas.inversion  -     optimization step took 0:00:08.722113
# 27-08-24 12:04:55 : INFO     : etas.inversion  - new parameters:
# 27-08-24 12:04:55 : INFO     : etas.inversion  - {   'a': 0.9204042956265011,
#     'gamma': -0.028572933534439127,
#     'log10_c': -2.606247282649815,
#     'log10_d': 2.087672791093497,
#     'log10_iota': None,
#     'log10_k0': -0.5859947881366084,
#     'log10_mu': -8.745140181481313,
#     'log10_tau': 3.875703188684667,
#     'omega': -0.054174109288402536,
#     'rho': 0.6894756638808666}
# 27-08-24 12:04:55 : INFO     : etas.inversion  -  difference to previous: 0.16949191060186766
# 27-08-24 12:04:55 : DEBUG    : etas.inversion  -  branching ratio: 0.9857859647888498
# 27-08-24 12:04:55 : INFO     : etas.inversion  -   iteration 8
# 27-08-24 12:04:55 : DEBUG    : etas.inversion  -     expectation step
# 27-08-24 12:04:55 : DEBUG    : etas.inversion  -     calculating gij
# 27-08-24 12:04:55 : DEBUG    : etas.inversion  -     calculating Pij
# 27-08-24 12:04:55 : DEBUG    : etas.inversion  -     calculating n_hat and l_hat
# 27-08-24 12:04:55 : DEBUG    : etas.inversion  -     expectation step took 0:00:00.090761
# 27-08-24 12:04:55 : DEBUG    : etas.inversion  - n_hat: 32.63920609997597
# 27-08-24 12:04:55 : DEBUG    : etas.inversion  - i_hat: 0
# 27-08-24 12:04:55 : DEBUG    : etas.inversion  - optimizing parameters
# 27-08-24 12:05:04 : DEBUG    : etas.inversion  -     optimization step took 0:00:08.414808
# 27-08-24 12:05:04 : INFO     : etas.inversion  - new parameters:
# 27-08-24 12:05:04 : INFO     : etas.inversion  - {   'a': 0.8960479946874398,
#     'gamma': -0.050853192049266596,
#     'log10_c': -2.613900095617561,
#     'log10_d': 2.096945605815983,
#     'log10_iota': None,
#     'log10_k0': -0.576495507684639,
#     'log10_mu': -8.768896733179442,
#     'log10_tau': 3.8806853399129606,
#     'omega': -0.05514744490357174,
#     'rho': 0.6900419935015443}
# 27-08-24 12:05:04 : INFO     : etas.inversion  -  difference to previous: 0.10333983575836042
# 27-08-24 12:05:04 : DEBUG    : etas.inversion  -  branching ratio: 0.991945576805059
# 27-08-24 12:05:04 : INFO     : etas.inversion  -   iteration 9
# 27-08-24 12:05:04 : DEBUG    : etas.inversion  -     expectation step
# 27-08-24 12:05:04 : DEBUG    : etas.inversion  -     calculating gij
# 27-08-24 12:05:04 : DEBUG    : etas.inversion  -     calculating Pij
# 27-08-24 12:05:04 : DEBUG    : etas.inversion  -     calculating n_hat and l_hat
# 27-08-24 12:05:04 : DEBUG    : etas.inversion  -     expectation step took 0:00:00.090708
# 27-08-24 12:05:04 : DEBUG    : etas.inversion  - n_hat: 31.651036334085827
# 27-08-24 12:05:04 : DEBUG    : etas.inversion  - i_hat: 0
# 27-08-24 12:05:04 : DEBUG    : etas.inversion  - optimizing parameters
# 27-08-24 12:05:13 : DEBUG    : etas.inversion  -     optimization step took 0:00:08.659105
# 27-08-24 12:05:13 : INFO     : etas.inversion  - new parameters:
# 27-08-24 12:05:13 : INFO     : etas.inversion  - {   'a': 0.8801328307030084,
#     'gamma': -0.06538122989591524,
#     'log10_c': -2.6180985504071868,
#     'log10_d': 2.102610769929902,
#     'log10_iota': None,
#     'log10_k0': -0.5705677254710887,
#     'log10_mu': -8.782248385350343,
#     'log10_tau': 3.883161742990282,
#     'omega': -0.055670138299921686,
#     'rho': 0.6903891457376891}
# 27-08-24 12:05:13 : INFO     : etas.inversion  -  difference to previous: 0.06293250382889158
# 27-08-24 12:05:13 : DEBUG    : etas.inversion  -  branching ratio: 0.9951906234919263
# 27-08-24 12:05:13 : INFO     : etas.inversion  -   iteration 10
# 27-08-24 12:05:13 : DEBUG    : etas.inversion  -     expectation step
# 27-08-24 12:05:13 : DEBUG    : etas.inversion  -     calculating gij
# 27-08-24 12:05:13 : DEBUG    : etas.inversion  -     calculating Pij
# 27-08-24 12:05:13 : DEBUG    : etas.inversion  -     calculating n_hat and l_hat
# 27-08-24 12:05:13 : DEBUG    : etas.inversion  -     expectation step took 0:00:00.119498
# 27-08-24 12:05:13 : DEBUG    : etas.inversion  - n_hat: 31.113390090686913
# 27-08-24 12:05:13 : DEBUG    : etas.inversion  - i_hat: 0
# 27-08-24 12:05:13 : DEBUG    : etas.inversion  - optimizing parameters
# 27-08-24 12:05:21 : DEBUG    : etas.inversion  -     optimization step took 0:00:08.408877
# 27-08-24 12:05:21 : INFO     : etas.inversion  - new parameters:
# 27-08-24 12:05:21 : INFO     : etas.inversion  - {   'a': 0.869880591379333,
#     'gamma': -0.07467496573053091,
#     'log10_c': -2.62040937013393,
#     'log10_d': 2.1060662688880485,
#     'log10_iota': None,
#     'log10_k0': -0.5668452279553079,
#     'log10_mu': -8.789688985749505,
#     'log10_tau': 3.8844340440911274,
#     'omega': -0.05595286416494333,
#     'rho': 0.6906153076982678}
# 27-08-24 12:05:21 : INFO     : etas.inversion  -  difference to previous: 0.03825658068456981
# 27-08-24 12:05:21 : DEBUG    : etas.inversion  -  branching ratio: 0.9969296725689006
# 27-08-24 12:05:21 : INFO     : etas.inversion  -   iteration 11
# 27-08-24 12:05:21 : DEBUG    : etas.inversion  -     expectation step
# 27-08-24 12:05:21 : DEBUG    : etas.inversion  -     calculating gij
# 27-08-24 12:05:21 : DEBUG    : etas.inversion  -     calculating Pij
# 27-08-24 12:05:21 : DEBUG    : etas.inversion  -     calculating n_hat and l_hat
# 27-08-24 12:05:21 : DEBUG    : etas.inversion  -     expectation step took 0:00:00.093957
# 27-08-24 12:05:21 : DEBUG    : etas.inversion  - n_hat: 30.818526882278945
# 27-08-24 12:05:21 : DEBUG    : etas.inversion  - i_hat: 0
# 27-08-24 12:05:21 : DEBUG    : etas.inversion  - optimizing parameters
# 27-08-24 12:05:29 : DEBUG    : etas.inversion  -     optimization step took 0:00:08.201683
# 27-08-24 12:05:29 : INFO     : etas.inversion  - new parameters:
# 27-08-24 12:05:29 : INFO     : etas.inversion  - {   'a': 0.8633414683387401,
#     'gamma': -0.08057026929066338,
#     'log10_c': -2.621702298276478,
#     'log10_d': 2.108197835880007,
#     'log10_iota': None,
#     'log10_k0': -0.5644273385270955,
#     'log10_mu': -8.793824444110877,
#     'log10_tau': 3.8850994454260883,
#     'omega': -0.056107778327443215,
#     'rho': 0.6907891518243502}
# 27-08-24 12:05:29 : INFO     : etas.inversion  -  difference to previous: 0.023406429148359324
# 27-08-24 12:05:29 : DEBUG    : etas.inversion  -  branching ratio: 0.997869258402112
# 27-08-24 12:05:29 : INFO     : etas.inversion  -   iteration 12
# 27-08-24 12:05:29 : DEBUG    : etas.inversion  -     expectation step
# 27-08-24 12:05:29 : DEBUG    : etas.inversion  -     calculating gij
# 27-08-24 12:05:30 : DEBUG    : etas.inversion  -     calculating Pij
# 27-08-24 12:05:30 : DEBUG    : etas.inversion  -     calculating n_hat and l_hat
# 27-08-24 12:05:30 : DEBUG    : etas.inversion  -     expectation step took 0:00:00.091660
# 27-08-24 12:05:30 : DEBUG    : etas.inversion  - n_hat: 30.655910100825125
# 27-08-24 12:05:30 : DEBUG    : etas.inversion  - i_hat: 0
# 27-08-24 12:05:30 : DEBUG    : etas.inversion  - optimizing parameters
# 27-08-24 12:05:37 : DEBUG    : etas.inversion  -     optimization step took 0:00:07.084897
# 27-08-24 12:05:37 : INFO     : etas.inversion  - new parameters:
# 27-08-24 12:05:37 : INFO     : etas.inversion  - {   'a': 0.85920686723415,
#     'gamma': -0.0842676689343839,
#     'log10_c': -2.6224464799114564,
#     'log10_d': 2.1095009416860306,
#     'log10_iota': None,
#     'log10_k0': -0.5628937626019511,
#     'log10_mu': -8.796122106002416,
#     'log10_tau': 3.885456721486981,
#     'omega': -0.05619308445128238,
#     'rho': 0.6909089934164826}
# 27-08-24 12:05:37 : INFO     : etas.inversion  -  difference to previous: 0.014272949782860304
# 27-08-24 12:05:37 : DEBUG    : etas.inversion  -  branching ratio: 0.9983805945519364
# 27-08-24 12:05:37 : INFO     : etas.inversion  -   iteration 13
# 27-08-24 12:05:37 : DEBUG    : etas.inversion  -     expectation step
# 27-08-24 12:05:37 : DEBUG    : etas.inversion  -     calculating gij
# 27-08-24 12:05:37 : DEBUG    : etas.inversion  -     calculating Pij
# 27-08-24 12:05:37 : DEBUG    : etas.inversion  -     calculating n_hat and l_hat
# 27-08-24 12:05:37 : DEBUG    : etas.inversion  -     expectation step took 0:00:00.093701
# 27-08-24 12:05:37 : DEBUG    : etas.inversion  - n_hat: 30.565682761359387
# 27-08-24 12:05:37 : DEBUG    : etas.inversion  - i_hat: 0
# 27-08-24 12:05:37 : DEBUG    : etas.inversion  - optimizing parameters
# 27-08-24 12:05:45 : DEBUG    : etas.inversion  -     optimization step took 0:00:08.014630
# 27-08-24 12:05:45 : INFO     : etas.inversion  - new parameters:
# 27-08-24 12:05:45 : INFO     : etas.inversion  - {   'a': 0.8565844476576054,
#     'gamma': -0.086604775442166,
#     'log10_c': -2.6228751046353045,
#     'log10_d': 2.1102999215626457,
#     'log10_iota': None,
#     'log10_k0': -0.5619217198975616,
#     'log10_mu': -8.79740221853087,
#     'log10_tau': 3.8856460533774557,
#     'omega': -0.05624124569380388,
#     'rho': 0.6909904178212788}
# 27-08-24 12:05:45 : INFO     : etas.inversion  -  difference to previous: 0.008758203455425474
# 27-08-24 12:05:45 : DEBUG    : etas.inversion  -  branching ratio: 0.9986637661464088
# 27-08-24 12:05:45 : INFO     : etas.inversion  -   iteration 14
# 27-08-24 12:05:45 : DEBUG    : etas.inversion  -     expectation step
# 27-08-24 12:05:45 : DEBUG    : etas.inversion  -     calculating gij
# 27-08-24 12:05:45 : DEBUG    : etas.inversion  -     calculating Pij
# 27-08-24 12:05:45 : DEBUG    : etas.inversion  -     calculating n_hat and l_hat
# 27-08-24 12:05:45 : DEBUG    : etas.inversion  -     expectation step took 0:00:00.093725
# 27-08-24 12:05:45 : DEBUG    : etas.inversion  - n_hat: 30.51532909245932
# 27-08-24 12:05:45 : DEBUG    : etas.inversion  - i_hat: 0
# 27-08-24 12:05:45 : DEBUG    : etas.inversion  - optimizing parameters
# 27-08-24 12:05:51 : DEBUG    : etas.inversion  -     optimization step took 0:00:06.439133
# 27-08-24 12:05:51 : INFO     : etas.inversion  - new parameters:
# 27-08-24 12:05:51 : INFO     : etas.inversion  - {   'a': 0.8549344452587397,
#     'gamma': -0.08807011745967247,
#     'log10_c': -2.62310039901426,
#     'log10_d': 2.1107941585418017,
#     'log10_iota': None,
#     'log10_k0': -0.5612990515916813,
#     'log10_mu': -8.798118261858805,
#     'log10_tau': 3.885754574194752,
#     'omega': -0.05626689570531576,
#     'rho': 0.6910468592454135}
# 27-08-24 12:05:51 : INFO     : etas.inversion  -  difference to previous: 0.005364199661242568
# 27-08-24 12:05:51 : DEBUG    : etas.inversion  -  branching ratio: 0.9988229047497047
# 27-08-24 12:05:51 : INFO     : etas.inversion  -   iteration 15
# 27-08-24 12:05:51 : DEBUG    : etas.inversion  -     expectation step
# 27-08-24 12:05:51 : DEBUG    : etas.inversion  -     calculating gij
# 27-08-24 12:05:51 : DEBUG    : etas.inversion  -     calculating Pij
# 27-08-24 12:05:51 : DEBUG    : etas.inversion  -     calculating n_hat and l_hat
# 27-08-24 12:05:51 : DEBUG    : etas.inversion  -     expectation step took 0:00:00.093727
# 27-08-24 12:05:51 : DEBUG    : etas.inversion  - n_hat: 30.487097165346263
# 27-08-24 12:05:51 : DEBUG    : etas.inversion  - i_hat: 0
# 27-08-24 12:05:51 : DEBUG    : etas.inversion  - optimizing parameters
# 27-08-24 12:05:56 : DEBUG    : etas.inversion  -     optimization step took 0:00:04.533888
# 27-08-24 12:05:56 : INFO     : etas.inversion  - new parameters:
# 27-08-24 12:05:56 : INFO     : etas.inversion  - {   'a': 0.8538948386760362,
#     'gamma': -0.08900397997712557,
#     'log10_c': -2.62328909267016,
#     'log10_d': 2.1110717019914556,
#     'log10_iota': None,
#     'log10_k0': -0.5610001298935908,
#     'log10_mu': -8.79852024492034,
#     'log10_tau': 3.88581542747255,
#     'omega': -0.05628367735735213,
#     'rho': 0.6910591956167861}
# 27-08-24 12:05:56 : INFO     : etas.inversion  -  difference to previous: 0.0032305822665423187
# 27-08-24 12:05:56 : DEBUG    : etas.inversion  -  branching ratio: 0.9989102848844249
# 27-08-24 12:05:56 : INFO     : etas.inversion  -   iteration 16
# 27-08-24 12:05:56 : DEBUG    : etas.inversion  -     expectation step
# 27-08-24 12:05:56 : DEBUG    : etas.inversion  -     calculating gij
# 27-08-24 12:05:56 : DEBUG    : etas.inversion  -     calculating Pij
# 27-08-24 12:05:56 : DEBUG    : etas.inversion  -     calculating n_hat and l_hat
# 27-08-24 12:05:56 : DEBUG    : etas.inversion  -     expectation step took 0:00:00.078136
# 27-08-24 12:05:56 : DEBUG    : etas.inversion  - n_hat: 30.47103037668424
# 27-08-24 12:05:56 : DEBUG    : etas.inversion  - i_hat: 0
# 27-08-24 12:05:56 : DEBUG    : etas.inversion  - optimizing parameters
# 27-08-24 12:06:00 : DEBUG    : etas.inversion  -     optimization step took 0:00:04.393442
# 27-08-24 12:06:00 : INFO     : etas.inversion  - new parameters:
# 27-08-24 12:06:00 : INFO     : etas.inversion  - {   'a': 0.8532542123653033,
#     'gamma': -0.08954790833083369,
#     'log10_c': -2.623354756699393,
#     'log10_d': 2.111249787302294,
#     'log10_iota': None,
#     'log10_k0': -0.5607597166377287,
#     'log10_mu': -8.798749179702321,
#     'log10_tau': 3.885822793560063,
#     'omega': -0.056293404076083554,
#     'rho': 0.6910822411544044}
# 27-08-24 12:06:00 : INFO     : etas.inversion  -  difference to previous: 0.001937790386218774
# 27-08-24 12:06:00 : DEBUG    : etas.inversion  -  branching ratio: 0.9989577401517792
# 27-08-24 12:06:00 : INFO     : etas.inversion  -   iteration 17
# 27-08-24 12:06:00 : DEBUG    : etas.inversion  -     expectation step
# 27-08-24 12:06:00 : DEBUG    : etas.inversion  -     calculating gij
# 27-08-24 12:06:00 : DEBUG    : etas.inversion  -     calculating Pij
# 27-08-24 12:06:01 : DEBUG    : etas.inversion  -     calculating n_hat and l_hat
# 27-08-24 12:06:01 : DEBUG    : etas.inversion  -     expectation step took 0:00:00.093729
# 27-08-24 12:06:01 : DEBUG    : etas.inversion  - n_hat: 30.462046537197956
# 27-08-24 12:06:01 : DEBUG    : etas.inversion  - i_hat: 0
# 27-08-24 12:06:01 : DEBUG    : etas.inversion  - optimizing parameters
# 27-08-24 12:06:04 : DEBUG    : etas.inversion  -     optimization step took 0:00:03.500407
# 27-08-24 12:06:04 : INFO     : etas.inversion  - new parameters:
# 27-08-24 12:06:04 : INFO     : etas.inversion  - {   'a': 0.8528525507828718,
#     'gamma': -0.08989464664911719,
#     'log10_c': -2.62338899366795,
#     'log10_d': 2.1113725843473055,
#     'log10_iota': None,
#     'log10_k0': -0.5605740538268207,
#     'log10_mu': -8.798877242558854,
#     'log10_tau': 3.885849541027518,
#     'omega': -0.05629660402686355,
#     'rho': 0.6911067392517396}
# 27-08-24 12:06:04 : INFO     : etas.inversion  -  difference to previous: 0.001273605097294024
# 27-08-24 12:06:04 : DEBUG    : etas.inversion  -  branching ratio: 0.9989841811088146
# 27-08-24 12:06:04 : INFO     : etas.inversion  -   iteration 18
# 27-08-24 12:06:04 : DEBUG    : etas.inversion  -     expectation step
# 27-08-24 12:06:04 : DEBUG    : etas.inversion  -     calculating gij
# 27-08-24 12:06:04 : DEBUG    : etas.inversion  -     calculating Pij
# 27-08-24 12:06:04 : DEBUG    : etas.inversion  -     calculating n_hat and l_hat
# 27-08-24 12:06:04 : DEBUG    : etas.inversion  -     expectation step took 0:00:00.109319
# 27-08-24 12:06:04 : DEBUG    : etas.inversion  - n_hat: 30.45696401406827
# 27-08-24 12:06:04 : DEBUG    : etas.inversion  - i_hat: 0
# 27-08-24 12:06:04 : DEBUG    : etas.inversion  - optimizing parameters
# 27-08-24 12:06:08 : DEBUG    : etas.inversion  -     optimization step took 0:00:03.742481
# 27-08-24 12:06:08 : INFO     : etas.inversion  - new parameters:
# 27-08-24 12:06:08 : INFO     : etas.inversion  - {   'a': 0.8526027338925396,
#     'gamma': -0.09010932124033784,
#     'log10_c': -2.6234121822551226,
#     'log10_d': 2.1114506992372983,
#     'log10_iota': None,
#     'log10_k0': -0.5604511166328723,
#     'log10_mu': -8.798949709650309,
#     'log10_tau': 3.8858618095220123,
#     'omega': -0.05629934142191157,
#     'rho': 0.6911245805713399}
# 27-08-24 12:06:08 : INFO     : etas.inversion  -  difference to previous: 0.0007940464532643007
# 27-08-24 12:06:08 : DEBUG    : etas.inversion  -  branching ratio: 0.9990003945119597
# 27-08-24 12:06:08 : INFO     : etas.inversion  -   stopping here. converged after 19 iterations.
# 27-08-24 12:06:08 : INFO     : etas.inversion  -     last expectation step
# 27-08-24 12:06:08 : DEBUG    : etas.inversion  -     calculating gij
# 27-08-24 12:06:08 : DEBUG    : etas.inversion  -     calculating Pij
# 27-08-24 12:06:08 : DEBUG    : etas.inversion  -     calculating n_hat and l_hat
# 27-08-24 12:06:08 : DEBUG    : etas.inversion  -     expectation step took 0:00:00.078106
# 27-08-24 12:06:08 : INFO     : etas.inversion  -     n_hat: 30.45405417285893
# 27-08-24 12:06:08 : INFO     : etas.inversion  -   Data will be stored in C:\Users\Dakshata\OneDrive - iitgn.ac.in\Thesis\Thesis\All_SEA\SEA1\outputdata
# Done!
